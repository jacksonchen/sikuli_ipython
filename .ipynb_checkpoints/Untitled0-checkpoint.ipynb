# %%
1+1
# Out:
# 2

# %%
matplotlib
# Out:
# <module 'matplotlib' from '/System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/matplotlib/__init__.pyc'>

# %%
import pandas as pd

# %%
plot(arange(10))

# %%
df = pd.read_csv('/Users/Jackson/dev/ipython/default_layouts.csv')
df.sort(['Package Name', 'Version Code'], inplace = True)
#df.drop_duplicates(['Package Name'], take_last = True)
# Out:
#                                           Package Name  Version Code  \
# 23                                            Game.NDK            27
# 6                                       Game.SpeedMoto            18
# 112                                            Uxpp.UC           112
# 1                       air.au.com.metro.DumbWaysToDie       1004003
# 108                        air.com.playtika.slotomania       1042000
# 163                           at.nerbrothers.SuperJump            16
# 169                               atticlab.bodyscanner            47
# 84                         br.com.rodrigokolb.realdrum            23
# 86                                  brain.age.analyzer            53
# 58                           ch.smalltech.battery.free           131
# 133                    ch.smalltech.ledflashlight.free           160
# 103                       cn.jingling.motu.photowonder           106
# 37                                  cn.wps.moffice_eng            72
# 36                                     co.vine.android       1400110
# 106                                    com.PinballGame             9
# 139               com.RunnerGames.game.JewelsDeluxe_AD            25
# 107                        com.StudioOnMars.CSPortable          3309
# 210                                  com.UCMobile.intl            89
# 157                       com.a0soft.gphone.aDataOnOff           274
# 35                            com.a0soft.gphone.app2sd           321
# 64                             com.accuweather.android            45
# 14                           com.aceviral.angrygranrun            24
# 34                                       com.adobe.air       3900138
# 47                                  com.adobe.psmobile            12
# 125                                   com.adobe.reader         85478
# 32                          com.advancedprocessmanager            68
# 155                              com.agilesoftresource        186537
# 144                                 com.aitype.android          1999
# 152                               com.alensw.PicFolder           125
# 145                    com.alienmanfc6.wheresmyandroid            92
# ..                                                 ...           ...
# 87                                 com.pandora.android          5005
# 63                                  com.picsart.studio            79
# 122                     com.rechild.advancedtaskkiller         10203
# 161                              com.roidapp.photogrid           125
# 73                                com.rovio.angrybirds          4000
# 199                            com.rovio.angrybirdsrio          1800
# 72                       com.rovio.angrybirdsspace.ads          1650
# 207               com.rovio.angrybirdsstarwars.ads.iap          1410
# 182                      com.samsung.swift.app.kiesair         23180
# 69                                      com.sec.chaton     302115000
# 213                                   com.sec.spp.push            46
# 77                              com.sgiggle.production    1386724633
# 115                       com.shootbubble.bubbledexlue            14
# 5                                     com.skype.raider      67405411
# 8        com.socialnmobile.dictapps.notepad.color.note           190
# 215                     com.surpax.ledflashlight.panel             4
# 175                                     com.tencent.mm           355
# 178                                com.twitter.android       3000517
# 156                                     com.viber.voip            47
# 25                                        com.whatsapp         48348
# 200               com.yahoo.mobile.client.android.mail       1311682
# 168                               com.zeptolab.ctr.ads            30
# 143                                      flipboard.app          2025
# 94   goldenshorestechnologies.brightestflashlight.free            27
# 173                              jp.naver.line.android           135
# 79                                          me.pou.app           157
# 41                                   net.zedge.android         40005
# 147                                org.mozilla.firefox    2013120507
# 214                                      tunein.player           116
# 203                          vStudio.Android.Camera360           434
#
#      Number of Default Layouts
# 23                           1
# 6                            1
# 112                        199
# 1                           19
# 108                         31
# 163                         46
# 169                         21
# 84                           5
# 86                          43
# 58                          56
# 133                         34
# 103                        213
# 37                         527
# 36                         111
# 106                          9
# 139                          1
# 107                         14
# 210                        132
# 157                         79
# 35                          51
# 64                         115
# 14                          19
# 34                           5
# 47                          54
# 125                         89
# 32                          43
# 155                         25
# 144                         64
# 152                         15
# 145                         46
# ..                         ...
# 87                         109
# 63                         402
# 122                         10
# 161                        190
# 73                           2
# 199                         17
# 72                           2
# 207                          1
# 182                         82
# 69                         202
# 213                         12
# 77                         306
# 115                         40
# 5                          146
# 8                           56
# 215                         10
# 175                        812
# 178                        271
# 156                        271
# 25                         153
# 200                        225
# 168                         50
# 143                        196
# 94                           1
# 173                        511
# 79                           4
# 41                          75
# 147                         80
# 214                        194
# 203                        180
#
# [109 rows x 3 columns]
